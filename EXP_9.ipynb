# %%
EXP_9

# %%
#Aim:To perform and analysis of KNN Algorithm

# %%
#Aim:To perform and analysis of support vector classifier

# %%
# Exp_9
# Name:Suhani Milind Gayakwad
# Roll no:16
# Sec:A
# SubjeCT:ET1
# Date:29/09/2025

# %% [markdown]
# # KNN CLASSIFIER

# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user'

# %%
os.chdir("C:\\Users\\USER\\Desktop")

# %%
data=pd.read_csv("heart - heart.csv")

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
x=data.drop("target", axis=1)
y=data["target"]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
#splitting the data into training and testing data sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred2=knn.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred2)

# %%
accuracy
# Out:
# 0.7317073170731707

# %%
x_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 835   49    1   2       118   149    0        0      126      0      0.8
# 137   64    0   0       180   325    0        1      154      1      0.0
# 534   54    0   2       108   267    0        0      167      0      0.0
# 495   59    1   0       135   234    0        1      161      0      0.5
# 244   51    1   2       125   245    1        0      166      0      2.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 700   41    1   2       130   214    0        0      168      0      2.0
# 71    61    1   0       140   207    0        0      138      1      1.9
# 106   51    1   0       140   299    0        1      173      1      1.6
# 270   43    1   0       110   211    0        1      161      0      0.0
# 860   52    1   0       112   230    0        1      160      0      0.0
#
#      slope  ca  thal
# 835      2   3     2
# 137      2   0     2
# 534      2   0     2
# ...

# %%
x_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 835   49    1   2       118   149    0        0      126      0      0.8
# 137   64    0   0       180   325    0        1      154      1      0.0
# 534   54    0   2       108   267    0        0      167      0      0.0
# 495   59    1   0       135   234    0        1      161      0      0.5
# 244   51    1   2       125   245    1        0      166      0      2.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 700   41    1   2       130   214    0        0      168      0      2.0
# 71    61    1   0       140   207    0        0      138      1      1.9
# 106   51    1   0       140   299    0        1      173      1      1.6
# 270   43    1   0       110   211    0        1      161      0      0.0
# 860   52    1   0       112   230    0        1      160      0      0.0
#
#      slope  ca  thal
# 835      2   3     2
# 137      2   0     2
# 534      2   0     2
# ...

# %%
x_test
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 527   62    0   0       124   209    0        1      163      0      0.0
# 359   53    0   2       128   216    0        0      115      0      0.0
# 447   55    1   0       160   289    0        0      145      1      0.8
# 31    50    0   1       120   244    0        1      162      0      1.1
# 621   48    1   0       130   256    1        0      150      1      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 832   68    1   2       118   277    0        1      151      0      1.0
# 796   41    1   1       135   203    0        1      132      0      0.0
# 644   44    1   2       120   226    0        1      169      0      0.0
# 404   61    1   0       140   207    0        0      138      1      1.9
# 842   58    1   2       112   230    0        0      165      0      2.5
#
#      slope  ca  thal
# 527      2   0     2
# 359      2   0     0
# 447      1   1     3
# ...

# %%
y_train
# Out:
# 835    0
# 137    1
# 534    1
# 495    1
# 244    1
#       ..
# 700    1
# 71     0
# 106    0
# 270    1
# 860    0
# Name: target, Length: 820, dtype: int64

# %%
y_test
# Out:
# 527    1
# 359    1
# 447    0
# 31     1
# 621    0
#       ..
# 832    1
# 796    1
# 644    1
# 404    0
# 842    0
# Name: target, Length: 205, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
# Step 1: Generate random numbers
data = np.random.randint(1, 20, size=8) # 8 random numbers between 1 and 20
# Step 2: Create bar chart
x = np.arange(len(data)) # positions for bars
# Step 3: Change bar colors
colors = ['green', 'blue', 'red']
plt.bar(x, data, color=colors)
# Add labels
plt.xlabel("Index")
plt.ylabel("Random Value")
plt.title("Random Numbers Bar Chart")
# Show plot
plt.show()
